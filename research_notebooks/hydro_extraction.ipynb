# %%
# TODO:
# возможные глоб. фичи:
# groupby: year, month, id (в различных коминациях)
# функции: mean, std, mean_diff

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import pandas as pd
import numpy as np

from datetime import datetime, timedelta
import utils
import os
from collections.abc import Iterable

# %%
root_dir = "../"
data_dir = os.path.join(root_dir, "working_data/")

water_levels_path = os.path.join(data_dir, "water_levels.csv")
# corrs_dists_path = os.path.join(data_dir, "corrs_and_dists.csv")

# %%
hydro_coords = pd.read_csv(data_dir + "hydro_posts_coords.csv")

# %%
water_levels = pd.read_csv(water_levels_path)
water_levels["date"] = pd.to_datetime(water_levels["date"], format="%Y-%m-%d")
water_levels.set_index(["id", "date"], inplace=True)
water_levels = utils.reduce_memory_usage(water_levels)

water_levels.head()

# corr_and_nearest = pd.read_csv(corrs_dists_path)
# corr_and_nearest.head()
# Out:
#                  max_level
# id   date
# 5001 1984-01-01      258.0
#      1984-01-02      255.0
#      1984-01-03      252.0
#      1984-01-04      248.0
#      1984-01-05      244.0

# %%
def fill_missing_dates(water_levels, fill_val=np.nan):
    dates = water_levels.index.get_level_values(1)
    min_date, max_date = dates.min(), dates.max()
    
    new_index = pd.MultiIndex.from_product([water_levels.index.get_level_values(0).unique(), 
                                            pd.date_range(min_date, max_date, name="date")])
    water_levels = water_levels.reindex(new_index, fill_value=fill_val)
    return water_levels

# water_levels = fill_missing_dates(water_levels)
# water_levels.head()

# %%
def extract_features(df, func, func_args_list):
    id_groups = df.groupby(by="id")
    features = []
    
    for func_args in func_args_list:
        if not isinstance(func_args, Iterable):
            func_args = (func_args,)
        func_out = func(id_groups, *func_args)
            
        features.append(func_out)
        
    features_df = pd.concat(features, axis=1)
    return features_df


def lag(grouped, lag):
    feature = grouped.shift(lag)
    
    feature_name = f"lag_{lag}"
    feature = rename_first_col(feature, feature_name)
    
    return feature


def stat(grouped, func, lag, winsize):
    shifted_grouped = grouped.shift(lag).groupby("id")
    
    print("start extracting")
    feature = grouped.rolling(winsize, min_periods=1).agg(func)
    print("end!")
    
    feature = drop_redundant_agg_indexes(feature)
    
    feature_name = f"{func.__name__}_{lag}_{winsize}"
    feature = rename_first_col(feature, feature_name)
    
    return feature


def drop_redundant_agg_indexes(df):
    df.index = df.index.droplevel(0) # agg creates second id col
    return df


def rename_first_col(df, new_name):
    old_name = df.columns[0]
    new_name = f"{old_name}_" + new_name
    
    return df.rename(columns={old_name: new_name})

# def mean_previous_years(df):
#     feature = 

    
# def last_year_records(df)

# %%
def diff_lag(grouped, ndays):
    differences = grouped.diff(1).groupby("id").shift(1).groupby("id") #group again to roll by groups not whole df
    
    feature_names = [f"diff_{i}" for i in range(1, ndays+1)]
    diff_lags = differences.rolling(ndays, min_periods=1) # need shift to get only previous values without current one
    
    diff_lags = all_rolling_lags(diff_lags, ndays)
    
    diff_lags_df = pd.DataFrame(diff_lags, columns=feature_names)
    return diff_lags_df
        
    
def all_rolling_lags(roll, ndays):
    vals = []
    for window in enumerate(roll):
        window_vals_flipped = window[1].values[:, 0]
        # window is took from earlier days to later, so we flip it to lag format (1 col is lag 1 day ago etc)
        window_vals = np.flip(window_vals_flipped)
        
        win_len = window_vals.shape[0]
        
        if win_len < ndays:
            padding_array = np.full(ndays - win_len, np.nan)
            padded_window_values = np.concatenate((window_vals, padding_array))
            
        else:
            padded_window_values = window_vals
            
        vals.append(padded_window_values)
    return np.array(vals)

# diff_lags = extract_features(water_levels, diff_lag, [7])
# diff_lags.index = water_levels.index
# diff_lags.head(3)

# %%
def calc_diff_lags_stats(diff_lags, funcs):
    
    features = []
    for func in funcs:
        print(func.__name__)
        f_name = f"diff_{func.__name__}"
        feature = diff_lags.apply(func, axis=1)
        feature.name = f_name
        features.append(feature)
    
    features_df = pd.concat(features, axis=1)
    return features_df

# %%
# diff_lags_stats = calc_diff_lags_stats(diff_lags, [np.nanmean, np.nanstd])
# diff_lags_stats.head()

# %%
# lags = extract_features(water_levels, lag, np.arange(1, 8))
# lags.head()

# %%
# stat_config = [
#     [np.nanmean, 1, 7],
#     [np.nanmean, 1, 30],
#     [np.nanstd, 1, 30],
    
#     [np.nanmax, 1, 7],
#     [np.nanmin, 1, 7],
    
#     [np.nanmax, 1, 30],
#     [np.nanmin, 1, 30]
# ]

# stats = extract_features(water_levels, stat, stat_config)
# stats.head()

# %%
def past_years_stats(df, funcs):
    months = df.index.get_level_values("date").month
    days = df.index.get_level_values("date").day
    station = df.index.get_level_values("id")
    
    same_doy = df["max_level"].groupby([months, days, station])
    same_doy_previous = same_doy.shift(1).groupby([months, days, station])
    
    features = []
    for func in funcs:
        print(f"agg func: {func.__name__}")
    #agg from previous because we have no water level of x year's doy when calc features for this year's doy
        feature = same_doy_previous.expanding(min_periods=1).agg(func) 
        f_name = f"doy_{func.__name__}"
#         feature = rename_first_col(feature, f_name)
        feature.name = f_name
        features.append(feature)
        
    features_df = pd.concat(features, axis=1)
    features_df = features_df.droplevel([0, 1, 2]).sort_index(level=["id", "date"])
        
    return features_df

# %%
def lag_from_previous(series, lag):
    return series.iloc[-lag] # use .values if breaks

def lag1(series):
    return lag_from_previous(series, 1)

def lag2(series):
    return lag_from_previous(series, 2)

def func_for_n_last(series, func, n_last):
#     start_idx = max(len(series) - n_last, 0)
    n_last_series = series.iloc[-n_last:] # use .values if breaks
    return func(n_last_series)

def mean_last_5_years(series):
    return func_for_n_last(series, np.nanmean, 5)

def std_last_5_years(series):
    return func_for_n_last(series, np.nanstd, 5)

# doy_stats = past_years_stats(water_levels, [mean_last_5_years, std_last_5_years, np.nanmean, np.nanstd, lag1, lag2])

# %%
# lags.head()
# stats.head()
# doy_stats.head() #also includes lags
# diff_lags.head()
# diff_lags_stats.head()

# check indexes are same
def check_same_idxs(dfs):
    first_df = dfs[0]
    for df in dfs[1:]:
        if not first_df.index.equals(df.index):
            return False
    return True

# feature_dfs = (lags, stats, doy_stats, diff_lags, diff_lags_stats)
# if check_same_idxs(feature_dfs):
#     all_features = pd.concat(feature_dfs, axis=1)
# else:
#     raise ValueError("dfs have different indexes, cant concatenate")

# all_features.head()

# %%
# разумеется, нужно добавить сами предсказываемые значения

# water_levels.rename(columns={"max_level": "target"}, inplace=True)
# all_features = all_features.merge(water_levels, left_index=True, right_index=True)
# all_features.head()

# %% [markdown]
# ### add lon lat

# %%
# all_features = pd.read_csv(os.path.join(data_dir, "hydro_features.csv"))
# all_features["date"] = pd.to_datetime(all_features["date"])
# all_features.set_index(["id", "date"], inplace=True)
# all_features.head()
# Out:
#                  max_level_lag_1  max_level_lag_2  max_level_lag_3  \
# id   date
# 5001 1984-01-01              NaN              NaN              NaN
#      1984-01-02            258.0              NaN              NaN
#      1984-01-03            255.0            258.0              NaN
#      1984-01-04            252.0            255.0            258.0
#      1984-01-05            248.0            252.0            255.0
#
#                  max_level_lag_4  max_level_lag_5  max_level_lag_6  \
# id   date
# 5001 1984-01-01              NaN              NaN              NaN
#      1984-01-02              NaN              NaN              NaN
#      1984-01-03              NaN              NaN              NaN
#      1984-01-04              NaN              NaN              NaN
#      1984-01-05            258.0              NaN              NaN
#
#                  max_level_lag_7  max_level_nanmean_1_7  \
# id   date
# 5001 1984-01-01              NaN                 258.00
#      1984-01-02              NaN                 256.50
#      1984-01-03              NaN                 255.00
#      1984-01-04              NaN                 253.25
#      1984-01-05              NaN                 251.40
#
#                  max_level_nanmean_1_30  max_level_nanstd_1_30  ...  diff_1  \
# id   date                                                       ...
# 5001 1984-01-01                  258.00                    NaN  ...     NaN
#      1984-01-02                  256.50               2.121320  ...    -3.0
#      1984-01-03                  255.00               3.000000  ...    -3.0
#      1984-01-04                  253.25               4.272002  ...    -4.0
#      1984-01-05                  251.40               5.549775  ...    -4.0
#
#                  diff_2  diff_3  diff_4  diff_5  diff_6  diff_7  diff_nanmean  \
# id   date
# 5001 1984-01-01     NaN     NaN     NaN     NaN     NaN     NaN           NaN
#      1984-01-02     NaN     NaN     NaN     NaN     NaN     NaN     -3.000000
#      1984-01-03    -3.0     NaN     NaN     NaN     NaN     NaN     -3.000000
#      1984-01-04    -3.0    -3.0     NaN     NaN     NaN     NaN     -3.333333
#      1984-01-05    -4.0    -3.0    -3.0     NaN     NaN     NaN     -3.500000
#
#                  diff_nanstd  target
# id   date
# 5001 1984-01-01          NaN   258.0
#      1984-01-02     0.000000   255.0
#      1984-01-03     0.000000   252.0
#      1984-01-04     0.471405   248.0
#      1984-01-05     0.500000   244.0
#
# [5 rows x 30 columns]

# %%
# hydro_coords = pd.read_csv(data_dir + "hydro_posts_coords.csv")
# hydro_coords.head()

# %%
# all_features = all_features.reset_index().merge(hydro_coords, on="id", how="left")
# all_features.set_index(["id", "date"], inplace=True)

# %% [markdown]
# ### extract calendar features

# %%
# date = all_features.index.get_level_values("date")
# doy = date.dayofyear
# all_features["doy"] = doy

# %%
def df_doy(df):
    date = df.reset_index()["date"]
    return date.dayofyear

# %%
def extract_diff_features(df):
    diff_lags = extract_features(df, diff_lag, [7])
    diff_lags.index = df.index
    
    diff_lags_stats = calc_diff_lags_stats(diff_lags, [np.nanmean, np.nanstd])
    
    features = pd.concat([diff_lags, diff_lags_stats], axis=1)
    return features

# %%
def safe_features_concat(features_dfs):
    if check_same_idxs(feature_dfs):
        return pd.concat(feature_dfs, axis=1)
    else:
        raise ValueError("dfs have different indexes, cant concatenate")

# %%
def merge_features_with_coords(features, coords):
    merged = features.reset_index().merge(coords, on="id", how="left")
    merged.set_index(["id", "date"], inplace=True)
    
    return merged

# %%
def water_levels_features(water_levels):
    water_levels = fill_missing_dates(water_levels)
    
    stat_config = [
    [np.nanmean, 1, 7],
    [np.nanmean, 1, 30],
    [np.nanstd, 1, 30],
    
    [np.nanmax, 1, 7],
    [np.nanmin, 1, 7],
    
    [np.nanmax, 1, 30],
    [np.nanmin, 1, 30]
    ]
    stats = extract_features(water_levels, stat, stat_config)
    lags = extract_features(water_levels, lag, np.arange(1, 8))
    
    diff_features = extract_diff_features(water_levels)
    doy_stats = past_years_stats(water_levels, [mean_last_5_years, std_last_5_years, np.nanmean, np.nanstd, lag1, lag2])
    doy = df_doy(all_features)
    
    all_features = safe_features_concat([lags, stats, diff_features, doy_stats, water_levels, doy])
    
    return all_features

# %%
def hydro_feature_extraction(water_levels, hydro_coords,):
    all_features = water_levels_features(water_levels)
    all_features = merge_features_with_coords(all_features, hydro_coords)
    
    return all_features

# %%
def water_levels_features_latest_date(water_levels):
    """Extracting features only for last date in water_levels,
    used for step predict."""
    water_levels = fill_missing_dates(water_levels)
    
    stat_config = [
    [np.nanmean, 1, 7],
    [np.nanmean, 1, 30],
    [np.nanstd, 1, 30],
    
    [np.nanmax, 1, 7],
    [np.nanmin, 1, 7],
    
    [np.nanmax, 1, 30],
    [np.nanmin, 1, 30]
    ]
    water_levels_last_31_days = n_latest_dates(water_levels, 31)
    stats = extract_features(water_levels_last_31_days, stat, stat_config)
    
    water_levels_last_9_days = n_latest_dates(water_levels, 9)
    diff_features = extract_diff_features(water_levels_last_9_days)
    lags = extract_features(water_levels, lag, np.arange(1, 8))
    
    doy_stats = past_years_stats(water_levels, [mean_last_5_years, std_last_5_years, np.nanmean, np.nanstd, lag1, lag2])
    doy = df_doy(all_features)
    
    all_features = safe_features_concat([lags, stats, diff_features, doy_stats, water_levels, doy])
    all_features = keep_latest_date(all_features)
    return all_features
                                 
    

def n_latest_dates(df, n):
    dates = df.reset_index()["date"]
    last_n_uniq_dates = sorted(dates.unique())[-n:]
    
    mask_last_n_dates = dates.isin(last_n_uniq_dates).values
    
    return df[mask_last_n_dates]

def keep_latest_date(df):
    dates = df.reset_index()["date"]
    latest_date = dates.max()
    
    mask_latest_date = dates.values == latest_date
    
    return df[mask_latest_date]

# %%
def last_day_hydro_feature_extraction(water_levels, hydro_coords):
    all_features = water_levels_features_latest_date(water_levels)
    all_features = merge_features_with_coords(all_features, hydro_coords)
    
    return all_features

# %%
last_day = last_day_hydro_feature_extraction(water_levels, hydro_coords)
# Out:
# start extracting
# end!
# start extracting
# end!
# start extracting
# end!
# start extracting
# end!
# start extracting
# end!
# start extracting
# end!
# start extracting
# end!
# nanmean
# nanstd
# agg func: mean_last_5_years
# <ipython-input-32-4d8e939413b3>:13: RuntimeWarning: Mean of empty slice
#   return func(n_last_series)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-66-b9d60dda3a5e> in <module>
# ----> 1 last_day = last_day_hydro_feature_extraction(water_levels, hydro_coords)
#
# <ipython-input-65-9b3d96a3d88a> in last_day_hydro_feature_extraction(water_levels, hydro_coords)
#       1 def last_day_hydro_feature_extraction(water_levels, hydro_coords):
# ----> 2     all_features = water_levels_features_latest_date(water_levels)
#       3     all_features = merge_features_with_coords(all_features, hydro_coords)
#       4
#       5     return all_features
#
# <ipython-input-64-85eb01a7014a> in water_levels_features_latest_date(water_levels)
#      22     lags = extract_features(water_levels, lag, np.arange(1, 8))
#      23
# ---> 24     doy_stats = past_years_stats(water_levels, [mean_last_5_years, std_last_5_years, np.nanmean, np.nanstd, lag1, lag2])
#      25     doy = df_doy(all_features)
#      26
#
# <ipython-input-31-a7078e3c1a16> in past_years_stats(df, funcs)
#      11         print(f"agg func: {func.__name__}")
#      12     #agg from previous because we have no water level of x year's doy when calc features for this year's doy
# ---> 13         feature = same_doy_previous.expanding(min_periods=1).agg(func)
#      14         f_name = f"doy_{func.__name__}"
#      15 #         feature = rename_first_col(feature, f_name)
#
# ~/.local/share/virtualenvs/aij20-flood-lIcseS5N/lib/python3.8/site-packages/pandas/core/window/expanding.py in aggregate(self, func, *args, **kwargs)
#     123     )
#     124     def aggregate(self, func, *args, **kwargs):
# --> 125         return super().aggregate(func, *args, **kwargs)
#     126
#     127     agg = aggregate
#
# ~/.local/share/virtualenvs/aij20-flood-lIcseS5N/lib/python3.8/site-packages/pandas/core/window/rolling.py in aggregate(self, func, *args, **kwargs)
#     602         result, how = self._aggregate(func, *args, **kwargs)
#     603         if result is None:
# --> 604             return self.apply(func, raw=False, args=args, kwargs=kwargs)
#     605         return result
#     606
#
# ~/.local/share/virtualenvs/aij20-flood-lIcseS5N/lib/python3.8/site-packages/pandas/core/window/expanding.py in apply(self, func, raw, engine, engine_kwargs, args, kwargs)
#     143         kwargs=None,
#     144     ):
# --> 145         return super().apply(
#     146             func,
#     147             raw=raw,
#
# ~/.local/share/virtualenvs/aij20-flood-lIcseS5N/lib/python3.8/site-packages/pandas/core/window/rolling.py in apply(self, func, raw, engine, engine_kwargs, args, kwargs)
#    1386
#    1387         # name=func & raw=raw for WindowGroupByMixin._apply
# -> 1388         return self._apply(
#    1389             apply_func,
#    1390             center=center,
#
# ~/.local/share/virtualenvs/aij20-flood-lIcseS5N/lib/python3.8/site-packages/pandas/core/window/common.py in _apply(self, func, center, require_min_periods, floor, is_weighted, name, use_numba_cache, **kwargs)
#      90             return x.apply(name, *args, **kwargs)
#      91
# ---> 92         return self._groupby.apply(f)
#      93
#      94
#
# ~/.local/share/virtualenvs/aij20-flood-lIcseS5N/lib/python3.8/site-packages/pandas/core/groupby/generic.py in apply(self, func, *args, **kwargs)
#     224     )
#     225     def apply(self, func, *args, **kwargs):
# --> 226         return super().apply(func, *args, **kwargs)
#     227
#     228     @doc(
#
# ~/.local/share/virtualenvs/aij20-flood-lIcseS5N/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     857         with option_context("mode.chained_assignment", None):
#     858             try:
# --> 859                 result = self._python_apply_general(f, self._selected_obj)
#     860             except TypeError:
#     861                 # gh-20949
#
# ~/.local/share/virtualenvs/aij20-flood-lIcseS5N/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f, data)
#     890             data after applying f
#     891         """
# --> 892         keys, values, mutated = self.grouper.apply(f, data, self.axis)
#     893
#     894         return self._wrap_applied_output(
#
# ~/.local/share/virtualenvs/aij20-flood-lIcseS5N/lib/python3.8/site-packages/pandas/core/groupby/ops.py in apply(self, f, data, axis)
#     211             # group might be modified
#     212             group_axes = group.axes
# --> 213             res = f(group)
#     214             if not _is_indexed_like(res, group_axes):
#     215                 mutated = True
#
# ~/.local/share/virtualenvs/aij20-flood-lIcseS5N/lib/python3.8/site-packages/pandas/core/window/common.py in f(x, name, *args)
#      88                 return getattr(x, name)(*args, **kwargs)
#      89
# ---> 90             return x.apply(name, *args, **kwargs)
#      91
#      92         return self._groupby.apply(f)
#
# ~/.local/share/virtualenvs/aij20-flood-lIcseS5N/lib/python3.8/site-packages/pandas/core/window/expanding.py in apply(self, func, raw, engine, engine_kwargs, args, kwargs)
#     143         kwargs=None,
#     144     ):
# --> 145         return super().apply(
#     146             func,
#     147             raw=raw,
#
# ~/.local/share/virtualenvs/aij20-flood-lIcseS5N/lib/python3.8/site-packages/pandas/core/window/rolling.py in apply(self, func, raw, engine, engine_kwargs, args, kwargs)
#    1386
#    1387         # name=func & raw=raw for WindowGroupByMixin._apply
# -> 1388         return self._apply(
#    1389             apply_func,
#    1390             center=center,
#
# ~/.local/share/virtualenvs/aij20-flood-lIcseS5N/lib/python3.8/site-packages/pandas/core/window/rolling.py in _apply(self, func, center, require_min_periods, floor, is_weighted, name, use_numba_cache, **kwargs)
#     586                     result = np.apply_along_axis(calc, self.axis, values)
#     587                 else:
# --> 588                     result = calc(values)
#     589                     result = np.asarray(result)
#     590
#
# ~/.local/share/virtualenvs/aij20-flood-lIcseS5N/lib/python3.8/site-packages/pandas/core/window/rolling.py in calc(x)
#     574                         closed=self.closed,
#     575                     )
# --> 576                     return func(x, start, end, min_periods)
#     577
#     578             else:
#
# ~/.local/share/virtualenvs/aij20-flood-lIcseS5N/lib/python3.8/site-packages/pandas/core/window/rolling.py in apply_func(values, begin, end, min_periods, raw)
#    1413             if not raw:
#    1414                 values = Series(values, index=self.obj.index)
# -> 1415             return window_func(values, begin, end, min_periods)
#    1416
#    1417         return apply_func
#
# pandas/_libs/window/aggregations.pyx in pandas._libs.window.aggregations.roll_generic_fixed()
#
# <ipython-input-32-4d8e939413b3> in mean_last_5_years(series)
#      14
#      15 def mean_last_5_years(series):
# ---> 16     return func_for_n_last(series, np.nanmean, 5)
#      17
#      18 def std_last_5_years(series):
#
# <ipython-input-32-4d8e939413b3> in func_for_n_last(series, func, n_last)
#      11 #     start_idx = max(len(series) - n_last, 0)
#      12     n_last_series = series.iloc[-n_last:] # use .values if breaks
# ---> 13     return func(n_last_series)
#      14
#      15 def mean_last_5_years(series):
#
# <__array_function__ internals> in nanmean(*args, **kwargs)
#
# ~/.local/share/virtualenvs/aij20-flood-lIcseS5N/lib/python3.8/site-packages/numpy/lib/nanfunctions.py in nanmean(a, axis, dtype, out, keepdims)
#     935
#     936     """
# --> 937     arr, mask = _replace_nan(a, 0)
#     938     if mask is None:
#     939         return np.mean(arr, axis=axis, dtype=dtype, out=out, keepdims=keepdims)
#
# ~/.local/share/virtualenvs/aij20-flood-lIcseS5N/lib/python3.8/site-packages/numpy/lib/nanfunctions.py in _replace_nan(a, val)
#      94
#      95     """
# ---> 96     a = np.asanyarray(a)
#      97
#      98     if a.dtype == np.object_:
#
# ~/.local/share/virtualenvs/aij20-flood-lIcseS5N/lib/python3.8/site-packages/numpy/core/_asarray.py in asanyarray(a, dtype, order)
#     134
#     135     """
# --> 136     return array(a, dtype, copy=False, order=order, subok=True)
#     137
#     138
#
# ~/.local/share/virtualenvs/aij20-flood-lIcseS5N/lib/python3.8/site-packages/pandas/core/series.py in __array__(self, dtype)
#     795               dtype='datetime64[ns]')
#     796         """
# --> 797         return np.asarray(self.array, dtype)
#     798
#     799     # ----------------------------------------------------------------------
#
# ~/.local/share/virtualenvs/aij20-flood-lIcseS5N/lib/python3.8/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ~/.local/share/virtualenvs/aij20-flood-lIcseS5N/lib/python3.8/site-packages/pandas/core/arrays/numpy_.py in __array__(self, dtype)
#     208     # NumPy Array Interface
#     209
# --> 210     def __array__(self, dtype=None) -> np.ndarray:
#     211         return np.asarray(self._ndarray, dtype=dtype)
#     212
#
# KeyboardInterrupt:

# %%
all_features.to_csv(os.path.join(data_dir, "hydro_features.csv"))

# %% [markdown]
# #### проверяем, что всё извлеклось мы хотели

# %%
# st_example = stats.loc[5019]
# st_example.iloc[:10] #first values
# st_example[st_example.index.year == 1990].iloc[:10] # values from n year

# st_example = water_levels.loc[5019]
# st_example.iloc[:10] #first values
# st_example[st_example.index.year == 1990].iloc[:10] # values from second year
# st_example[(st_example.index.month == 1) & (st_example.index.day == 1)].iloc[:10]
